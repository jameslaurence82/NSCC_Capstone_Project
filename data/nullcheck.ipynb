# %%
import pandas as pd
# drug = pd.read_csv('DrugTable.csv', delimiter = '|')
product = pd.read_csv('DrugProductTable.csv', delimiter = '|')
# price = pd.read_csv('DrugPriceTable.csv', delimiter = '|')
# food_interaction = pd.read_csv('FoodInteraction.csv', delimiter = '|')
# drug_interaction = pd.read_csv('drugInteraction.csv', delimiter = '|')

# %%
product.head(20)
product['drugisOTC'] = product['drugisOTC'].astype(str)
product['drugisApproved'] = product['drugisApproved'].astype(str)

# %%
# Check and print data types
print("Data Types:")
print(product.dtypes)

# Check and print maximum character lengths for string columns
print("\nMaximum Character Lengths for String Columns:")
for column in product.select_dtypes(include=['object']).columns:  # 'object' dtype is often used for strings in pandas
    max_length = product[column].astype(str).map(len).max()
    print(f"{column}: {max_length}")
# Out:
# Data Types:
# drugId                 object
# drugGenericName        object
# drugLabeller           object
# drugDosageForm         object
# drugStrength           object
# drugRouteUsed          object
# drugisOTC              object
# drugisApproved         object
# drugApprovalCountry    object
# drugApprovalSource     object
# dtype: object
#
# Maximum Character Lengths for String Columns:
# drugId: 7
# drugGenericName: 367
# drugLabeller: 166
# drugDosageForm: 82
# drugStrength: 36
# drugRouteUsed: 129
# drugisOTC: 5
# drugisApproved: 5
# drugApprovalCountry: 6
# drugApprovalSource: 7

# %%
price.head(20)
# Out:
#      drugId                               drugPriceDescription  drugPriceCost  \
# 0   DB00001                                Refludan 50 mg vial         273.19
# 1   DB00003                             Lufyllin 200 mg tablet           3.21
# 2   DB00003                                 Lufyllin-gg tablet           3.84
# 3   DB00003                      Lufyllin-GG 200-200 mg tablet           3.99
# 4   DB00003                                Lufyllin-400 tablet           4.62
# 5   DB00003                             Lufyllin 400 mg tablet           4.81
# 6   DB00003                            Pulmozyme 1 mg/ml ampul          37.05
# 7   DB00003  Pulmozyme 1 mg/ml Solution 2.5ml Plastic Conta...          77.06
# 8   DB00003                 Lufyllin-GG 100-100 mg/15ml Elixir           0.60
# 9   DB00004                              Ontak 150 mcg/ml vial         878.40
# 10  DB00005                                   Enbrel 25 mg kit         250.37
# ...

# %%
product.head(20)
# Out:
#      drugId   drugGenericName             drugLabeller  \
# 0   DB00001          Refludan                    Bayer
# 1   DB00001          Refludan                    Bayer
# 2   DB00001          Refludan   Celgene Europe Limited
# 3   DB00001          Refludan   Celgene Europe Limited
# 4   DB00001          Refludan   Celgene Europe Limited
# 5   DB00001          Refludan   Celgene Europe Limited
# 6   DB00002           Erbitux              ImClone LLC
# 7   DB00002           Erbitux              ImClone LLC
# 8   DB00002           Erbitux             Imclone, Llc
# 9   DB00002           Erbitux        Merck Europe B.V.
# 10  DB00002           Erbitux        Merck Europe B.V.
# 11  DB00003         Pulmozyme          Genentech, Inc.
# 12  DB00003  Pulmozyme 1mg/ml        Hoffmann La Roche
# 13  DB00004             Ontak            Eisai Limited
# 14  DB00005          Benepali  Samsung Bioepis Nl B.V.
# 15  DB00005          Benepali  Samsung Bioepis Nl B.V.
# ...

# %%
food_interaction.head(20)
# Out:
#      drugId                         foodInteractionDescription
# 0   DB00001  Avoid herbs and supplements with anticoagulant...
# 1   DB00002                                                NaN
# 2   DB00003                                                NaN
# 3   DB00004                                                NaN
# 4   DB00005                                                NaN
# 5   DB00006  Avoid echinacea. Avoid herbs and supplements w...
# 6   DB00007                                                NaN
# 7   DB00008                            Drink plenty of fluids.
# 8   DB00009  Avoid herbs and supplements with anticoagulant...
# 9   DB00010                                                NaN
# 10  DB00011                                     Avoid alcohol.
# 11  DB00012  Administer iron supplement. When initiating an...
# 12  DB00013  Avoid herbs and supplements with anticoagulant...
# 13  DB00014                                                NaN
# ...

# %%
drug_interaction.head(20)
# Out:
#      drugId interactionId             interactionName  \
# 0   DB00001       DB06605                    Apixaban
# 1   DB00001       DB06695        Dabigatran etexilate
# 2   DB00001       DB01254                   Dasatinib
# 3   DB00001       DB01609                 Deferasirox
# 4   DB00001       DB01586        Ursodeoxycholic acid
# 5   DB00001       DB02123  Glycochenodeoxycholic Acid
# 6   DB00001       DB02659                 Cholic Acid
# 7   DB00001       DB02691            Glycocholic acid
# 8   DB00001       DB03619            Deoxycholic acid
# 9   DB00001       DB04348            Taurocholic acid
# 10  DB00001       DB05990            Obeticholic acid
# 11  DB00001       DB06777       Chenodeoxycholic acid
# 12  DB00001       DB08833  Taurochenodeoxycholic acid
# 13  DB00001       DB08834   Tauroursodeoxycholic acid
# 14  DB00001       DB08857                   Bamet-UD2
# 15  DB00001       DB11622          Dehydrocholic acid
# ...

# %%
drug.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16575 entries, 0 to 16574
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   drugId               16575 non-null  object
#  1   drugName             16575 non-null  object
#  2   drugDescription      9373 non-null   object
#  3   drugIndication       4250 non-null   object
#  4   drugPharmacodynamic  3116 non-null   object
#  5   drugToxicity         2508 non-null   object
# dtypes: object(6)
# memory usage: 777.1+ KB

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448348 entries, 0 to 448347
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   drugId               448348 non-null  object
#  1   drugGenericName      448347 non-null  object
#  2   drugLabeller         448339 non-null  object
#  3   drugDosageForm       447710 non-null  object
#  4   drugStrength         231173 non-null  object
#  5   drugRouteUsed        447889 non-null  object
#  6   drugisOTC            448348 non-null  bool
#  7   drugisApproved       448348 non-null  bool
#  8   drugApprovalCountry  448348 non-null  object
#  9   drugApprovalSource   448348 non-null  object
# dtypes: bool(2), object(8)
# memory usage: 28.2+ MB

# %%
price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11807 entries, 0 to 11806
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   drugId                11807 non-null  object
#  1   drugPriceDescription  11807 non-null  object
#  2   drugPriceCost         11807 non-null  float64
#  3   drugPriceCurrency     11807 non-null  object
#  4   drugPriceUnit         11807 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 461.3+ KB

# %%
food_interaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16575 entries, 0 to 16574
# Data columns (total 2 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   drugId                      16575 non-null  object
#  1   foodInteractionDescription  1402 non-null   object
# dtypes: object(2)
# memory usage: 259.1+ KB

# %%
drug_interaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2840496 entries, 0 to 2840495
# Data columns (total 4 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   drugId                  object
#  1   interactionId           object
#  2   interactionName         object
#  3   interactionDescription  object
# dtypes: object(4)
# memory usage: 86.7+ MB
